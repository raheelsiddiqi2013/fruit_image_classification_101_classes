# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
plt.rcParams.update({'font.size': 18})
y = [99.75, 99.89, 99.97, 99.79, 99.86, 99.68, 99.82, 99.95, 99.93, 99.86, 99.68, 99.73]
z = [86, 97, 83, 82, 82, 127, 70, 98, 112, 133, 80, 67]
n = ['VGG16 based model','VGG19 based model','Xception based model','ResNet50 based model','InceptionV3 based model','InceptionResNetV2 based model','MobileNet based model','DenseNet121 based model','DenseNet169 based model','DenseNet201 based model','MobileNetV2 based model','FruitNet']

fig, ax = plt.subplots(figsize=(20, 10))
ax.scatter(z, y,s=100,marker='s')

for i, txt in enumerate(n):
    ax.annotate(txt, (z[i], y[i]))
ax.set_xlabel('Test Time (ms/step)')
ax.set_ylabel('Accuracy Rate (%)')
# Out:
# Text(0, 0.5, 'Accuracy Rate (%)')
